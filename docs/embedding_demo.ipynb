# %% [markdown]
# # Demonstration of Embeddings for Similarity Measure
# Description of the demo.

# %% [markdown]
# Firstly, let us make the necessary imports.

# %%
import pandas as pd
from operations.calling import Embeddings
from embeddings.embeddings import LatentFeatureAnalysis, SimilarityMeasurement

# %% [markdown]
# # Import the data
# The data consists of movie plots scraped from Wikipedia. In this
# case move plots are movies belonging from the adventure genre,
# starting from 1980s up to the 2020s.

# %%
raw_data = pd.read_csv(
    filepath_or_buffer=r"D:\Projects\025_scenario_writing\other\output\screenplays_adventure_films_1980_2020_prepared.csv"
)

# %% [markdown]
# It is fairly easy to generate embeddings.

# %%
film_summary_embeddings = []
for film_name, film_summary in zip(raw_data.loc[:, 'film_name'], raw_data.loc[:, 'content']):
    print(f'Making embedding for {film_name}')
    embedding = Embeddings(raw_text=film_summary)
    embedding.generate_embeddings()
    film_summary_embeddings.extend([embedding.get_embeddings()])

film_data = pd.DataFrame.from_records(film_summary_embeddings)
# Out:
# Making embedding for The Awakening
# Making embedding for The Blue Lagoon
# Making embedding for The Blues Brothers
# Making embedding for Cannibal Holocaust
# Making embedding for The Dogs of War
# Making embedding for The Empire Strikes Back
# Making embedding for The Gods Must Be Crazy
# Making embedding for Hawk the Slayer
# Making embedding for Herbie Goes Bananas
# Making embedding for The Island
# Making embedding for Kagemusha
# Making embedding for The Last Flight of Noah's Ark
# Making embedding for The Mountain Men
# Making embedding for Pirates of the 20th Century
# Making embedding for Popeye
# Making embedding for Raise the Titanic
# Making embedding for The Sea Wolves
# Making embedding for Superman II
# Making embedding for Clash of the Titans
# Making embedding for Death Hunt
# Making embedding for Escape from New York
# Making embedding for For Your Eyes Only
# Making embedding for The Fox and the Hound
# Making embedding for Gallipoli
# Making embedding for Great White
# Making embedding for High Risk
# Making embedding for The Last Chase
# Making embedding for Lion of the Desert
# Making embedding for Masada
# Making embedding for Quest for Fire
# Making embedding for Raiders of the Lost Ark
# Making embedding for Roar
# Making embedding for Time Bandits
# Making embedding for Zorro, The Gay Blade
# Making embedding for Ace of Aces
# Making embedding for The Beastmaster
# Making embedding for Conan the Barbarian
# Making embedding for The Dark Crystal
# Making embedding for E.T. the Extra-Terrestrial
# Making embedding for Firefox
# Making embedding for Fitzcarraldo
# Making embedding for The Flight of Dragons
# Making embedding for The Last Unicorn
# Making embedding for Les Maîtres du temps
# Making embedding for The Pirate Movie
# Making embedding for The Scarlet Pimpernel
# Making embedding for Space Adventure Cobra: The Movie
# Making embedding for Star Trek II: The Wrath of Khan
# Making embedding for The Sword and the Sorcerer
# Making embedding for The Year of Living Dangerously
# Making embedding for The Black Stallion Returns
# Making embedding for Conquest
# Making embedding for El Norte
# Making embedding for Fire and Ice
# Making embedding for Krull
# Making embedding for National Lampoon's Vacation
# Making embedding for Never Cry Wolf
# Making embedding for Octopussy
# Making embedding for The Pirates of Penzance
# Making embedding for Return of the Jedi
# Making embedding for Spacehunter: Adventures in the Forbidden Zone
# Making embedding for The Bounty
# Making embedding for Conan the Destroyer
# Making embedding for Dune
# Making embedding for Greystoke: The Legend of Tarzan, Lord of the Apes
# Making embedding for The Hit
# Making embedding for Indiana Jones and the Temple of Doom
# Making embedding for The Last Starfighter
# Making embedding for The Master of Ballantrae
# Making embedding for Les Morfalous
# Making embedding for The NeverEnding Story
# Making embedding for A Passage to India
# Making embedding for The Perils of Gwendoline in the Land of the Yik-Yak
# Making embedding for Romancing the Stone
# Making embedding for Ronia, the Robber's Daughter
# Making embedding for Sheena
# Making embedding for Star Trek III: The Search for Spock
# Making embedding for Sword of the Valiant
# Making embedding for The Aviator
# Making embedding for Back to the Future
# Making embedding for Barbarian Queen
# Making embedding for Black Arrow
# Making embedding for The Black Cauldron
# Making embedding for The Emerald Forest
# Making embedding for Explorers
# Making embedding for The Goonies
# Making embedding for The Jewel of the Nile
# Making embedding for The Journey of Natty Gann
# Making embedding for King David
# Making embedding for Ladyhawke
# Making embedding for Legend
# Making embedding for Lupin the 3rd: The Golden Legend of Babylon
# Making embedding for Mad Max Beyond Thunderdome
# Making embedding for National Lampoon's European Vacation
# Making embedding for Orion's Belt
# Making embedding for Pee-wee's Big Adventure
# Making embedding for Rambo: First Blood Part II
# Making embedding for Red Sonja
# Making embedding for Return to Oz
# Making embedding for Runaway Train
# Making embedding for Santa Claus: The Movie
# Making embedding for Spies Like Us
# Making embedding for A View to a Kill
# Making embedding for Allan Quatermain and the Lost City of Gold
# Making embedding for An American Tail
# Making embedding for Castle in the Sky
# Making embedding for The Clan of the Cave Bear
# Making embedding for Crocodile Dundee
# Making embedding for Firewalker
# Making embedding for The Golden Child
# Making embedding for Highlander
# Making embedding for King Kong Lives
# Making embedding for Labyrinth
# Making embedding for The Mosquito Coast
# Making embedding for Pirates
# Making embedding for Sky Bandits
# Making embedding for Solarbabies
# Making embedding for SpaceCamp
# Making embedding for Star Trek IV: The Voyage Home
# Making embedding for Tai-Pan
# Making embedding for Armour of God
# Making embedding for The Barbarians
# Making embedding for Benji the Hunted
# Making embedding for A Chinese Ghost Story
# Making embedding for The Chipmunk Adventure
# Making embedding for Cobra Verde
# Making embedding for Ishtar
# Making embedding for The Lighthorsemen
# Making embedding for The Living Daylights
# Making embedding for Masters of the Universe
# Making embedding for Mio in the Land of Faraway
# Making embedding for Pathfinder
# Making embedding for The Princess Bride
# Making embedding for Straight to Hell
# Making embedding for Superman IV: The Quest for Peace
# Making embedding for White Water Summer
# Making embedding for Yeelen
# Making embedding for The Adventures of Baron Munchausen
# Making embedding for Alien from L.A.
# Making embedding for The Bear
# Making embedding for The Beast
# Making embedding for Bloodstone
# Making embedding for Crocodile Dundee II
# Making embedding for The Deceivers
# Making embedding for The Gods Must Be Crazy 2
# Making embedding for Gorillas in the Mist
# Making embedding for The Great Outdoors
# Making embedding for The Land Before Time
# Making embedding for Outlaw of Gor
# Making embedding for Rambo III
# Making embedding for The Rescue
# Making embedding for Vibes
# Making embedding for Willow
# Making embedding for The Abyss
# Making embedding for Babar: The Movie
# Making embedding for Back to the Future Part II
# Making embedding for Batman
# Making embedding for Bill & Ted's Excellent Adventure
# Making embedding for Cheetah
# Making embedding for Crusoe
# Making embedding for Erik the Viking
# Making embedding for Marrakech Express
# Making embedding for Nostos: The Return
# Making embedding for Old Gringo
# Making embedding for The Return of the Musketeers
# Making embedding for Sinbad of the Seven Seas
# Making embedding for Slipstream
# Making embedding for Star Trek V: The Final Frontier
# Making embedding for Bullet in the Head
# Making embedding for Captain Fracassa's Journey
# Making embedding for A Chinese Ghost Story II
# Making embedding for Cyrano de Bergerac
# Making embedding for DuckTales the Movie: Treasure of the Lost Lamp
# Making embedding for The Hunt for Red October
# Making embedding for Jetsons: The Movie
# Making embedding for Lord of the Flies
# Making embedding for Predator 2
# Making embedding for The Rescuers Down Under
# Making embedding for The Sheltering Sky
# Making embedding for Shipwrecked
# Making embedding for Total Recall
# Making embedding for Treasure Island
# Making embedding for White Hunter Black Heart
# Making embedding for An American Tail: Fievel Goes West
# Making embedding for Armour of God II: Operation Condor
# Making embedding for At Play in the Fields of the Lord
# Making embedding for Black Robe
# Making embedding for A Chinese Ghost Story 3
# Making embedding for City Slickers
# Making embedding for Hook
# Making embedding for Isabelle Eberhardt
# Making embedding for K2
# Making embedding for Motorama
# Making embedding for The NeverEnding Story II: The Next Chapter
# Making embedding for Once Upon a Time in China
# Making embedding for Pure Luck
# Making embedding for Return to the Blue Lagoon
# Making embedding for Robin Hood: Prince of Thieves
# Making embedding for The Rocketeer
# Making embedding for Star Trek VI: The Undiscovered Country
# Making embedding for Thelma & Louise
# Making embedding for La Totale!
# Making embedding for The White Viking
# Making embedding for 1492: Conquest of Paradise
# Making embedding for Aladdin
# Making embedding for Army of Darkness
# Making embedding for Batman Returns
# Making embedding for Captain Ron
# Making embedding for Far and Away
# Making embedding for The Last of the Mohicans
# Making embedding for The Lost World
# Making embedding for Medicine Man
# Making embedding for New Dragon Gate Inn
# Making embedding for Return to the Lost World
# Making embedding for Royal Tramp
# Making embedding for Royal Tramp 2
# Making embedding for Ruby Cairo
# Making embedding for The Adventures of Huck Finn
# Making embedding for Alive
# Making embedding for The Bride with White Hair
# Making embedding for Cool Runnings
# Making embedding for Dennis the Menace
# Making embedding for A Far Off Place
# Making embedding for Fong Sai-yuk
# Making embedding for Fong Sai-yuk II
# Making embedding for Free Willy
# Making embedding for The Fugitive
# Making embedding for Homeward Bound: The Incredible Journey
# Making embedding for Iron Monkey
# Making embedding for Jurassic Park
# Making embedding for Robin Hood: Men in Tights
# Making embedding for Super Mario Bros.
# Making embedding for The Three Musketeers
# Making embedding for The Ascent
# Making embedding for Baby's Day Out
# Making embedding for Cabin Boy
# Making embedding for City Slickers II: The Legend of Curly's Gold
# Making embedding for Clear and Present Danger
# Making embedding for Gunmen
# Making embedding for Highlander III: The Sorcerer
# Making embedding for The Jungle Book
# Making embedding for Lassie
# Making embedding for The Lion King
# Making embedding for Men of War
# Making embedding for No Escape
# Making embedding for The Pagemaster
# Making embedding for The Return of Jafar
# Making embedding for Revenge of the Musketeers
# Making embedding for The River Wild
# Making embedding for The Secret of Roan Inish
# Making embedding for Squanto: A Warrior's Tale
# Making embedding for Star Trek Generations
# Making embedding for Stargate
# Making embedding for Surviving the Game
# Making embedding for Taxandria
# Making embedding for The Amazing Panda Adventure
# Making embedding for Apollo 13
# Making embedding for Batman Forever
# Making embedding for Beyond Rangoon
# Making embedding for Braveheart
# Making embedding for The City of Lost Children
# Making embedding for Congo
# Making embedding for Cutthroat Island
# Making embedding for Die Hard with a Vengeance
# Making embedding for First Knight
# Making embedding for Gold Diggers: The Secret of Bear Mountain
# Making embedding for GoldenEye
# Making embedding for Jumanji
# Making embedding for Mortal Kombat
# Making embedding for Pocahontas
# Making embedding for Sahara
# Making embedding for Tom and Huck
# Making embedding for Toy Story
# Making embedding for Waterworld
# Making embedding for 101 Dalmatians
# Making embedding for Danger Zone
# Making embedding for Dragonheart
# Making embedding for Executive Decision
# Making embedding for Flipper
# Making embedding for Fly Away Home
# Making embedding for The Ghost and the Darkness
# Making embedding for Homeward Bound II: Lost in San Francisco
# Making embedding for Independence Day
# Making embedding for The Island of Dr. Moreau
# Making embedding for Matilda
# Making embedding for Mission: Impossible
# Making embedding for Muppet Treasure Island
# Making embedding for The NeverEnding Story III
# Making embedding for North Star
# Making embedding for The Phantom
# Making embedding for The Quest
# Making embedding for Space Jam
# Making embedding for Star Trek: First Contact
# Making embedding for White Squall
# Making embedding for Amistad
# Making embedding for Anaconda
# Making embedding for Austin Powers: International Man of Mystery
# Making embedding for Dante's Peak
# Making embedding for The Edge
# Making embedding for The Fifth Element
# Making embedding for Kull the Conqueror
# Making embedding for The Lost World: Jurassic Park
# Making embedding for Men in Black
# Making embedding for Mortal Kombat: Annihilation
# Making embedding for On Guard
# Making embedding for Passion in the Desert
# Making embedding for Paws
# Making embedding for The Postman
# Making embedding for Princess Mononoke
# Making embedding for Robinson Crusoe
# Making embedding for The Second Jungle Book: Mowgli & Baloo
# Making embedding for Seven Years in Tibet
# Making embedding for Starship Troopers
# Making embedding for Titanic
# Making embedding for Tomorrow Never Dies
# Making embedding for Twilight of the Ice Nymphs
# Making embedding for Zeus and Roxanne
# Making embedding for An American Tail: The Treasure of Manhattan Island
# Making embedding for Armageddon
# Making embedding for A Bug's Life
# Making embedding for Fear and Loathing in Las Vegas
# Making embedding for Goldrush: A Real Life Alaskan Adventure
# Making embedding for Legionnaire
# Making embedding for The Lion King II: Simba's Pride
# Making embedding for Lost in Space
# Making embedding for The Man in the Iron Mask
# Making embedding for The Mask of Zorro
# Making embedding for Pocahontas II: Journey to a New World
# Making embedding for The Prince of Egypt
# Making embedding for Six Days, Seven Nights
# Making embedding for Sphere
# Making embedding for Star Trek: Insurrection
# Making embedding for The 13th Warrior
# Making embedding for The Adventures of Elmo in Grouchland
# Making embedding for Asterix & Obelix Take On Caesar
# Making embedding for The Astronaut's Wife
# Making embedding for Austin Powers: The Spy Who Shagged Me
# Making embedding for Deep Blue Sea
# Making embedding for The Frenchman's Son
# Making embedding for Galaxy Quest
# Making embedding for The Messenger: The Story of Joan of Arc
# Making embedding for The Mummy
# Making embedding for Muppets from Space
# Making embedding for Star Wars: Episode I – The Phantom Menace
# Making embedding for Tarzan
# Making embedding for Three Kings
# Making embedding for Toy Story 2
# Making embedding for Virus
# Making embedding for Wild Wild West
# Making embedding for The World Is Not Enough
# Making embedding for 102 Dalmatians
# Making embedding for The Adventures of Rocky and Bullwinkle
# Making embedding for The Beach
# Making embedding for Cast Away
# Making embedding for Chicken Run
# Making embedding for Dinosaur
# Making embedding for Gladiator
# Making embedding for Mission to Mars
# Making embedding for O Brother, Where Art Thou?
# Making embedding for The Perfect Storm
# Making embedding for The Road to El Dorado
# Making embedding for Space Cowboys
# Making embedding for Supernova
# Making embedding for Thomas and the Magic Railroad
# Making embedding for Titan A.E.
# Making embedding for Tweety's High-Flying Adventure
# Making embedding for U-571
# Making embedding for Vertical Limit
# Making embedding for X-Men
# Making embedding for Atlantis: The Lost Empire
# Making embedding for Back to the Secret Garden
# Making embedding for Brotherhood of the Wolf
# Making embedding for The Bunker
# Making embedding for Cats & Dogs
# Making embedding for Daresalam
# Making embedding for Final Fantasy: The Spirits Within
# Making embedding for Harry Potter and the Philosopher's Stone
# Making embedding for Jimmy Neutron: Boy Genius
# Making embedding for Jurassic Park III
# Making embedding for A Knight's Tale
# Making embedding for Lady and the Tramp II: Scamp's Adventure
# Making embedding for Lagaan: Once Upon a Time in India
# Making embedding for Lara Croft: Tomb Raider
# Making embedding for The Legend of Suriyothai
# Making embedding for The Legend of Zu
# Making embedding for The Lord of the Rings: The Fellowship of the Ring
# Making embedding for The Mummy Returns
# Making embedding for The Musketeer
# Making embedding for The Other Side of Heaven
# Making embedding for Princess of Thieves
# Making embedding for Shrek
# Making embedding for Spirited Away
# Making embedding for Spy Kids
# Making embedding for The Adventures of Pluto Nash
# Making embedding for Asterix & Obelix: Mission Cleopatra
# Making embedding for Balto II: Wolf Quest
# Making embedding for Below
# Making embedding for The Count of Monte Cristo
# Making embedding for The Crocodile Hunter: Collision Course
# Making embedding for Die Another Day
# Making embedding for The Four Feathers
# Making embedding for Harry Potter and the Chamber of Secrets
# Making embedding for Ice Age
# Making embedding for K-19: The Widowmaker
# Making embedding for The Lord of the Rings: The Two Towers
# Making embedding for Rabbit-Proof Fence
# Making embedding for Reign of Fire
# Making embedding for Scooby-Doo
# Making embedding for The Scorpion King
# Making embedding for Snow Dogs
# Making embedding for Spy Kids 2: The Island of Lost Dreams
# Making embedding for Star Trek: Nemesis
# Making embedding for Star Wars: Episode II – Attack of the Clones
# Making embedding for The Time Machine
# Making embedding for xXx
# Making embedding for 2 Fast 2 Furious
# Making embedding for Agent Cody Banks
# Making embedding for And Starring Pancho Villa as Himself
# Making embedding for The Cat in the Hat
# Making embedding for El Cid: The Legend
# Making embedding for Cold Mountain
# Making embedding for Elf
# Making embedding for Fat Pizza
# Making embedding for Finding Nemo
# Making embedding for Johnny English
# Making embedding for The Jungle Book 2
# Making embedding for Kangaroo Jack
# Making embedding for Lara Croft: Tomb Raider – The Cradle of Life
# Making embedding for The Last Samurai
# Making embedding for The League of Extraordinary Gentlemen
# Making embedding for Looney Tunes: Back in Action
# Making embedding for The Lord of the Rings: The Return of the King
# Making embedding for Master and Commander: The Far Side of the World
# Making embedding for The Medallion
# Making embedding for Once Upon a Time in Mexico
# Making embedding for Ong-Bak: Muay Thai Warrior
# Making embedding for Peter Pan
# Making embedding for Pirates of the Caribbean: The Curse of the Black Pearl
# Making embedding for The Rundown
# Making embedding for Shanghai Knights
# Making embedding for Sinbad: Legend of the Seven Seas
# Making embedding for Sky Captain and the World of Tomorrow
# Making embedding for The Snow Walker
# Making embedding for Sword in the Moon
# Making embedding for Timeline
# Making embedding for Tokyo Godfathers
# Making embedding for Travellers and Magicians
# Making embedding for Alexander
# Making embedding for Anacondas: The Hunt for the Blood Orchid
# Making embedding for Around the World in 80 Days
# Making embedding for The Bourne Supremacy
# Making embedding for Catch That Kid
# Making embedding for The Chronicles of Riddick
# Making embedding for EuroTrip
# Making embedding for Flight of the Phoenix
# Making embedding for Harry Potter and the Prisoner of Azkaban
# Making embedding for Hidalgo
# Making embedding for Howl's Moving Castle
# Making embedding for The Incredibles
# Making embedding for King Arthur
# Making embedding for The Life Aquatic with Steve Zissou
# Making embedding for National Treasure
# Making embedding for The Polar Express
# Making embedding for Shark Tale
# Making embedding for Sky Captain and the World of Tomorrow
# Making embedding for The SpongeBob SquarePants Movie
# Making embedding for Team America: World Police
# Making embedding for Thunderbirds
# Making embedding for Troy
# Making embedding for Without a Paddle
# Making embedding for Beowulf & Grendel
# Making embedding for The Brothers Grimm
# Making embedding for Casanova
# Making embedding for Charlie and the Chocolate Factory
# Making embedding for Chicken Little
# Making embedding for The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Making embedding for The Descent
# Making embedding for Doom
# Making embedding for The Dukes of Hazzard
# Making embedding for Duma
# Making embedding for End of the Spear
# Making embedding for Harry Potter and the Goblet of Fire
# Making embedding for The Hitchhikers Guide to the Galaxy
# Making embedding for The Island
# Making embedding for Into the Blue
# Making embedding for King Kong
# Making embedding for The King Maker
# Making embedding for King of the Lost World
# Making embedding for Kingdom of Heaven
# Making embedding for Lassie
# Making embedding for The Legend of Zorro
# Making embedding for Love Wrecked
# Making embedding for MirrorMask
# Making embedding for The Promise
# Making embedding for River Queen
# Making embedding for Robots
# Making embedding for Sahara
# Making embedding for Serenity
# Making embedding for A Sound of Thunder
# Making embedding for Star Wars: Episode III – Revenge of the Sith
# Making embedding for Valiant
# Making embedding for Zathura: A Space Adventure
# Making embedding for 300
# Making embedding for Alatriste
# Making embedding for Apocalypto
# Making embedding for Asterix and the Vikings
# Making embedding for Blood Diamond
# Making embedding for Casino Royale
# Making embedding for The Curse of King Tut's Tomb
# Making embedding for Eragon
# Making embedding for Flicka
# Making embedding for Flushed Away
# Making embedding for Flyboys
# Making embedding for The Guardian
# Making embedding for Happy Feet
# Making embedding for Ice Age: The Meltdown
# Making embedding for Kokoda
# Making embedding for Little Miss Sunshine
# Making embedding for Night at the Museum
# Making embedding for Paprika
# Making embedding for The Pink Panther
# Making embedding for Pirates of the Caribbean: Dead Man's Chest
# Making embedding for Poseidon
# Making embedding for Rescue Dawn
# Making embedding for Sinking of Japan
# Making embedding for Superman Returns
# Making embedding for The Thief Lord
# Making embedding for Wolfhound
# Making embedding for X-Men: The Last Stand
# Making embedding for Arn – The Knight Templar
# Making embedding for Aztec Rex
# Making embedding for Battle for Terra
# Making embedding for Beowulf
# Making embedding for Black Water
# Making embedding for Bridge to Terabithia
# Making embedding for The Bucket List
# Making embedding for The Darjeeling Limited
# Making embedding for Harry Potter and the Order of the Phoenix
# Making embedding for In the Name of the King: A Dungeon Siege Tale
# Making embedding for Into the Wild
# Making embedding for Jacquou le Croquant
# Making embedding for The Last Legion
# Making embedding for Meet the Robinsons
# Making embedding for Mr. Bean's Holiday
# Making embedding for National Treasure: Book of Secrets
# Making embedding for Pathfinder
# Making embedding for Pirates of the Caribbean: At World's End
# Making embedding for Rogue
# Making embedding for The Simpsons Movie
# Making embedding for Stardust
# Making embedding for Wild Hogs
# Making embedding for 10,000 BC
# Making embedding for Arn – The Kingdom at Road's End
# Making embedding for Australia
# Making embedding for Beverly Hills Chihuahua
# Making embedding for Bolt
# Making embedding for De Brief voor de Koning
# Making embedding for The Children of Huang Shi
# Making embedding for The Chronicles of Narnia: Prince Caspian
# Making embedding for City of Ember
# Making embedding for The Flyboys
# Making embedding for Fool's Gold
# Making embedding for The Forbidden Kingdom
# Making embedding for The Good, the Bad, the Weird
# Making embedding for Indiana Jones and the Kingdom of the Crystal Skull
# Making embedding for Inkheart
# Making embedding for Journey to the Center of the Earth
# Making embedding for Jumper
# Making embedding for The Mummy: Tomb of the Dragon Emperor
# Making embedding for Nim's Island
# Making embedding for Outlander
# Making embedding for Quantum of Solace
# Making embedding for Rambo
# Making embedding for The Red Baron
# Making embedding for Roadside Romeo
# Making embedding for The Scorpion King 2: Rise of a Warrior
# Making embedding for Star Wars: The Clone Wars
# Making embedding for Strange Wilderness
# Making embedding for The Tale of Despereaux
# Making embedding for WALL-E
# Making embedding for 9
# Making embedding for Agora
# Making embedding for Avatar
# Making embedding for Dragonball Evolution
# Making embedding for Haeundae
# Making embedding for Harry Potter and the Half-Blood Prince
# Making embedding for Inglourious Basterds
# Making embedding for Into the Blue 2: The Reef
# Making embedding for Land of the Lost
# Making embedding for OSS 117: Lost in Rio
# Making embedding for Race to Witch Mountain
# Making embedding for Sherlock Holmes
# Making embedding for Sin Nombre
# Making embedding for Solomon Kane
# Making embedding for Star Trek
# Making embedding for Transformers: Revenge of the Fallen
# Making embedding for Up
# Making embedding for Valhalla Rising
# Making embedding for 13 Assassins
# Making embedding for The 7 Adventures of Sinbad
# Making embedding for Alice In Wonderland
# Making embedding for Centurion
# Making embedding for The Chronicles of Narnia: The Voyage of the Dawn Treader
# Making embedding for Clash of the Titans
# Making embedding for The Expendables
# Making embedding for The Extraordinary Adventures of Adèle Blanc-Sec
# Making embedding for Gulliver's Travels
# Making embedding for Harry Potter and the Deathly Hallows – Part 1
# Making embedding for Inception
# Making embedding for The Last Airbender
# Making embedding for Legend of the Guardians: The Owls of Ga'Hoole
# Making embedding for The Lost Future
# Making embedding for Nanga Parbat
# Making embedding for Percy Jackson & the Olympians: The Lightning Thief
# Making embedding for Prince of Persia: The Sands of Time
# Making embedding for Robin Hood
# Making embedding for The Sorcerer's Apprentice
# Making embedding for Tomorrow, When the War Began
# Making embedding for Toy Story 3
# Making embedding for Tron: Legacy
# Making embedding for The Way Back
# Making embedding for The Adventures of Tintin: The Secret of the Unicorn
# Making embedding for Cars 2
# Making embedding for Conan the Barbarian
# Making embedding for Dolphin Tale
# Making embedding for The Eagle
# Making embedding for The Grey
# Making embedding for Harry Potter and the Deathly Hallows: Part II
# Making embedding for The Hunter
# Making embedding for Johnny English Reborn
# Making embedding for A Lonely Place to Die
# Making embedding for The Lost Medallion: The Adventures of Billy Stone
# Making embedding for Machine Gun Preacher
# Making embedding for Mars Needs Moms
# Making embedding for Pirates of the Caribbean: On Stranger Tides
# Making embedding for Puss in Boots
# Making embedding for Rango
# Making embedding for Rio
# Making embedding for Rise of the Planet of the Apes
# Making embedding for Ronal the Barbarian
# Making embedding for Shaolin
# Making embedding for Spy Kids: All the Time in the World
# Making embedding for Thor
# Making embedding for The Three Musketeers
# Making embedding for Winnie the Pooh
# Making embedding for Your Highness
# Making embedding for The Avengers
# Making embedding for Battleship
# Making embedding for Brave
# Making embedding for The Dinosaur Project
# Making embedding for Fetih 1453
# Making embedding for The Hobbit: An Unexpected Journey
# Making embedding for HOUBA! On the Trail of the Marsupilami
# Making embedding for The Hunger Games
# Making embedding for Ice Age: Continental Drift
# Making embedding for John Carter
# Making embedding for Journey 2: The Mysterious Island
# Making embedding for Life of Pi
# Making embedding for The Pirates! In an Adventure with Scientists!
# Making embedding for Red Tails
# Making embedding for Rise of the Guardians
# Making embedding for Snow White and the Huntsman
# Making embedding for Tad, The Lost Explorer
# Making embedding for Wrath of the Titans
# Making embedding for 47 Ronin
# Making embedding for After Earth
# Making embedding for The A.R.K. Report
# Making embedding for All Is Lost
# Making embedding for Captain Phillips
# Making embedding for The Croods
# Making embedding for Epic
# Making embedding for Hammer of the Gods
# Making embedding for Hansel & Gretel: Witch Hunters
# Making embedding for The Hobbit: The Desolation of Smaug
# Making embedding for The Hunger Games: Catching Fire
# Making embedding for Jack the Giant Slayer
# Making embedding for Justin and the Knights of Valour
# Making embedding for The Lone Ranger
# Making embedding for Man of Steel
# Making embedding for Oz the Great and Powerful
# Making embedding for Pacific Rim
# Making embedding for The Physician
# Making embedding for The Secret Life of Walter Mitty
# Making embedding for Star Trek Into Darkness
# Making embedding for Thor: The Dark World
# Making embedding for The Admiral: Roaring Currents
# Making embedding for Big Game
# Making embedding for Black Sea
# Making embedding for Dracula Untold
# Making embedding for Exodus: Gods and Kings
# Making embedding for The Grand Budapest Hotel
# Making embedding for Guardians of the Galaxy
# Making embedding for Hector and the Search for Happiness
# Making embedding for The Hunger Games: Mockingjay – Part 1
# Making embedding for Interstellar
# Making embedding for Into the Woods
# Making embedding for Ironclad: Battle for Blood
# Making embedding for The Legend of Hercules
# Making embedding for Maleficent
# Making embedding for The Maze Runner
# Making embedding for Noah
# Making embedding for Outcast
# Making embedding for The Pyramid
# Making embedding for Seventh Son
# Making embedding for Theeb
# Making embedding for Transformers: Age of Extinction
# Making embedding for The Water Diviner
# Making embedding for Avengers: Age of Ultron
# Making embedding for Cinderella
# Making embedding for Eden
# Making embedding for Embrace of the Serpent
# Making embedding for Everest
# Making embedding for Fantastic Four
# Making embedding for The Hunger Games: Mockingjay – Part 2
# Making embedding for In the Heart of the Sea
# Making embedding for Jurassic World
# Making embedding for Kingsman: The Secret Service
# Making embedding for Last Knights
# Making embedding for The Last Witch Hunter
# Making embedding for Long Way North
# Making embedding for Mad Max: Fury Road
# Making embedding for Max
# Making embedding for Oddball
# Making embedding for Pan
# Making embedding for Point Break
# Making embedding for The Revenant
# Making embedding for Spectre
# Making embedding for The SpongeBob Movie: Sponge Out of Water
# Making embedding for Star Wars: The Force Awakens
# Making embedding for Tomorrowland
# Making embedding for The Walk
# Making embedding for Alice Through the Looking Glass
# Making embedding for Assassin's Creed
# Making embedding for Ben-Hur
# Making embedding for Fantastic Beasts and Where to Find Them
# Making embedding for The Finest Hours
# Making embedding for Gods of Egypt
# Making embedding for Gold
# Making embedding for The Great Wall
# Making embedding for Hunt for the Wilderpeople
# Making embedding for The Huntsman: Winter's War
# Making embedding for Independence Day: Resurgence
# Making embedding for Inferno
# Making embedding for The Jungle Book
# Making embedding for Last Days in the Desert
# Making embedding for The Last King
# Making embedding for The Legend of Tarzan
# Making embedding for Lion
# Making embedding for The Lost City of Z
# Making embedding for Moana
# Making embedding for The Odyssey
# Making embedding for Passengers
# Making embedding for Pee-Wee's Big Holiday
# Making embedding for Risen
# Making embedding for Rogue One
# Making embedding for Sausage Party
# Making embedding for Shin Godzilla
# Making embedding for Star Trek Beyond
# Making embedding for Swiss Army Man
# Making embedding for War Dogs
# Making embedding for Warcraft
# Making embedding for Zootopia
# Making embedding for 47 Meters Down
# Making embedding for A Dog's Purpose
# Making embedding for Guardians of the Galaxy Vol. 2
# Making embedding for Hostiles
# Making embedding for Jumanji: Welcome to the Jungle
# Making embedding for Jungle
# Making embedding for Justice League
# Making embedding for King Arthur: Legend of the Sword
# Making embedding for Kingsman: The Golden Circle
# Making embedding for Kong: Skull Island
# Making embedding for The Lego Ninjago Movie
# Making embedding for The Mountain Between Us
# Making embedding for The Mummy
# Making embedding for Okja
# Making embedding for Phoenix Wilder and the Great Elephant Adventure
# Making embedding for Pirates of the Caribbean: Dead Men Tell No Tales
# Making embedding for Renegades
# Making embedding for The Space Between Us
# Making embedding for Star Wars: The Last Jedi
# Making embedding for Valerian and the City of a Thousand Planets
# Making embedding for War for the Planet of the Apes
# Making embedding for Wolf Warrior 2
# Making embedding for Adrift
# Making embedding for Alpha
# Making embedding for Ant-Man and the Wasp
# Making embedding for Aquaman
# Making embedding for Fantastic Beasts: The Crimes of Grindelwald
# Making embedding for First Man
# Making embedding for Incredibles 2
# Making embedding for Isle of Dogs
# Making embedding for Jurassic World: Fallen Kingdom
# Making embedding for The Man Who Killed Don Quixote
# Making embedding for Maze Runner: The Death Cure
# Making embedding for The Meg
# Making embedding for Mortal Engines
# Making embedding for Mowgli: Legend of the Jungle
# Making embedding for Pacific Rim Uprising
# Making embedding for Peter Rabbit
# Making embedding for Ready Player One
# Making embedding for Robin Hood
# Making embedding for Samson
# Making embedding for The Shape of Water
# Making embedding for Solo: A Star Wars Story
# Making embedding for Tomb Raider
# Making embedding for A Wrinkle in Time
# Making embedding for 47 Meters Down: Uncaged
# Making embedding for The Aeronauts
# Making embedding for Aladdin
# Making embedding for Avengers: Endgame
# Making embedding for Dora and the Lost City of Gold
# Making embedding for How to Train Your Dragon: The Hidden World
# Making embedding for Jumanji: The Next Level
# Making embedding for The Kid Who Would Be King
# Making embedding for The Peanut Butter Falcon
# Making embedding for Rocko's Modern Life: Static Cling
# Making embedding for Star Wars: The Rise of Skywalker
# Making embedding for Triple Frontier
# Making embedding for The Call of the Wild
# Making embedding for The Christmas Chronicles 2
# Making embedding for Dolittle
# Making embedding for Love and Monsters
# Making embedding for The Old Guard
# Making embedding for Rogue
# Making embedding for Chernobyl: Abyss
# Making embedding for Dune
# Making embedding for F9
# Making embedding for The Green Knight
# Making embedding for The Ice Road
# Making embedding for Jungle Cruise
# Making embedding for The Last Duel
# Making embedding for The Batman
# Making embedding for The Lost City
# Making embedding for The Northman
# Making embedding for Uncharted

# %% [markdown]
# Once that embeddings are available, it is possible to perform some of
# the latent feature analyses. This will (a) preserve the most of the
# variance in the data, while at the same time providing us (b) to
# compute similiarity measurement at fraction of the cost, of what
# would be required if we would be using original embeddings.
# Computation over two dimensions is much faster than the computation
# over thousands of dimensions.

# %%
latent_feature_analyses = LatentFeatureAnalysis(
    data=film_data,
    method='PCA'
)
latent_feature_analyses.execute_analysis()

# %% [markdown]
# Let us now empirically evaluate the quality of reduction. This can be
# done by selecting a reference movie, and finding the most similar
# movies by their plots.

# %%
reference_movie = 'The Batman'
mask = raw_data.loc[:, 'film_name'] == reference_movie
reference_index = raw_data.index[mask].to_list()[0]

# %% [markdown]
# Now that index of the reference movie is retrieved, it is possible to
# utilize it in the measurement of similarity and identification of the
# most similar movie plots. Count of most similar movie plots is set to
# 10.

# %%
similarity_measurement = SimilarityMeasurement(
    data=latent_feature_analyses.get_reduction(),
    reference_index=reference_index,
    top_k=10,
    method='euclidean'
)
similarity_measurement.compute_distances()
top_most_similar = similarity_measurement.get_top_k()

# %% [markdown]
# Let us discover most similar movies, to our reference movie, according
# embeddings and LFA performed.

# %%
for most_similar in top_most_similar:
    print(raw_data.iloc[most_similar]['film_name'])
# Out:
# The Medallion
# The Postman
# National Treasure: Book of Secrets
# Jumper
# The Bounty
# Inglourious Basterds
# Blood Diamond
# Nanga Parbat
# Batman
# Around the World in 80 Days
